# %% [markdown]
# # Import Neccessary Libraries

# %%
from collections import Counter
from nltk.util import ngrams
from nltk.corpus import stopwords
import re
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ## Function to preprocess text and remove stop words

# %%
def preprocess_text(text):
    text = text.lower()  # Convert text to lowercase
    text = re.sub(r'[^a-z\s]', '', text)  # Remove non-alphabetic characters
    # Tokenize the text
    tokens = text.split()
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # Join the filtered tokens back into text
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# %% [markdown]
# # Set path for txt files to read and preprocess them

# %%
# Set file path to the 50 files
file_paths = [f'C:/Users/User/Dropbox/PC/Desktop/dataset txt/row{i}.txt' for i in range(1, 51)]

preprocessed_texts = []

# Read and preprocess each file
for file_path in file_paths:
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        preprocessed_text = preprocess_text(text)
        preprocessed_texts.append(preprocessed_text)

# %% [markdown]
# # Generate the N-grams

# %%
# Generate trigrams
trigrams = []
for text in preprocessed_texts:
    tokens = text.split()
    trigrams.extend(ngrams(tokens, 3))

# Count trigrams
trigram_counts = Counter(trigrams)

trigram_counts
# Out:
# Counter({('forward', 'looking', 'statements'): 15,
#          ('www', 'computron', 'com'): 15,
#          ('projected', 'speculative', 'price'): 10,
#          ('expect', 'projected', 'speculative'): 8,
#          ('speculative', 'price', 'next'): 8,
#          ('price', 'next', 'days'): 8,
#          ('ali', 'duty', 'free'): 8,
#          ('voice', 'internet', 'protocol'): 5,
#          ('looking', 'statements', 'within'): 5,
#          ('statements', 'within', 'meaning'): 5,
#          ('inherent', 'conflict', 'interest'): 5,
#          ('future', 'ooking', 'statements'): 5,
#          ('breaking', 'news', 'vocalscape'): 4,
#          ('news', 'vocalscape', 'inc'): 4,
#          ('vocalscape', 'inc', 'announces'): 4,
#          ('inc', 'announces', 'agreement'): 4,
#          ('announces', 'agreement', 'resell'): 4,
#          ('agreement', 'resell', 'mix'): 4,
#          ('resell', 'mix', 'network'): 4,
#          ('mix', 'network', 'services'): 4,
#          ('current', 'price', 'expect'): 4,
#          ('price', 'expect', 'projected'): 4,
#          ('next', 'days', 'expect'): 4,
#          ('days', 'expect', 'projected'): 4,
#          ('b', 'securities', 'exchange'): 4,
#          ('securities', 'exchange', 'act'): 4,
#          ('looking', 'statements', 'based'): 4,
#          ('number', 'risks', 'uncertainties'): 4,
#          ('risks', 'uncertainties', 'could'): 4,
#          ('uncertainties', 'could', 'cause'): 4,
#          ('information', 'provided', 'within'): 4,
#          ('pertaining', 'investing', 'stocks'): 4,
#          ('investing', 'stocks', 'securities'): 4,
#          ('stocks', 'securities', 'must'): 4,
#          ('securities', 'must', 'understood'): 4,
#          ('must', 'understood', 'information'): 4,
#          ('understood', 'information', 'provided'): 4,
#          ('information', 'provided', 'investment'): 4,
#          ('provided', 'investment', 'advice'): 4,
#          ('seek', 'advice', 'registered'): 4,
#          ('securities', 'representative', 'deciding'): 4,
#          ('representative', 'deciding', 'trade'): 4,
#          ('deciding', 'trade', 'stocks'): 4,
#          ('trade', 'stocks', 'featured'): 4,
#          ('stocks', 'featured', 'within'): 4,
#          ('construed', 'kind', 'investment'): 4,
#          ('kind', 'investment', 'advice'): 4,
#          ('montana', 'oil', 'gas'): 4,
#          ('one', 'stop', 'distributorjebel'): 4,
#          ('stop', 'distributorjebel', 'ali'): 4,
#          ('distributorjebel', 'ali', 'duty'): 4,
#          ('duty', 'free', 'zonedubai'): 4,
#          ('free', 'zonedubai', 'uae'): 4,
#          ('zonedubai', 'uae', 'www'): 4,
#          ('uae', 'www', 'computron'): 4,
#          ('computron', 'com', 'latest'): 4,
#          ('com', 'latest', 'clearance'): 4,
#          ('latest', 'clearance', 'sale'): 4,
#          ('clearance', 'sale', 'listing'): 4,
#          ('sale', 'listing', 'contact'): 4,
#          ('listing', 'contact', 'sales'): 4,
#          ('contact', 'sales', 'department'): 4,
#          ('details', 'please', 'send'): 4,
#          ('please', 'send', 'enquiries'): 4,
#          ('send', 'enquiries', 'dealers'): 4,
#          ('enquiries', 'dealers', 'emirates'): 4,
#          ('dealers', 'emirates', 'net'): 4,
#          ('emirates', 'net', 'aeor'): 4,
#          ('net', 'aeor', 'contact'): 4,
#          ('aeor', 'contact', 'via'): 4,
#          ('contact', 'via', 'www'): 4,
#          ('via', 'www', 'computron'): 4,
#          ('computron', 'com', 'compaq'): 4,
#          ('com', 'compaq', 'hewlett'): 4,
#          ('compaq', 'hewlett', 'packard'): 4,
#          ('hewlett', 'packard', 'com'): 4,
#          ('packard', 'com', 'dell'): 4,
#          ('com', 'dell', 'intel'): 4,
#          ('dell', 'intel', 'iomega'): 4,
#          ('intel', 'iomega', 'epson'): 4,
#          ('iomega', 'epson', 'aopen'): 4,
#          ('epson', 'aopen', 'creative'): 4,
#          ('aopen', 'creative', 'toshiba'): 4,
#          ('creative', 'toshiba', 'apc'): 4,
#          ('toshiba', 'apc', 'cisco'): 4,
#          ('apc', 'cisco', 'us'): 4,
#          ('cisco', 'us', 'robotics'): 4,
#          ('us', 'robotics', 'microsoft'): 4,
#          ('robotics', 'microsoft', 'canon'): 4,
#          ('microsoft', 'canon', 'intellinet'): 4,
#          ('canon', 'intellinet', 'targus'): 4,
#          ('intellinet', 'targus', 'viewsonic'): 4,
#          ('targus', 'viewsonic', 'ibm'): 4,
#          ('viewsonic', 'ibm', 'sony'): 4,
#          ('ibm', 'sony', 'lots'): 4,
#          ('sony', 'lots', 'complaints'): 4,
#          ('lots', 'complaints', 'suggestions'): 4,
#          ('complaints', 'suggestions', 'contact'): 4,
#          ('suggestions', 'contact', 'customerservice'): 4,
#          ('contact', 'customerservice', 'computron'): 4,
#          ('customerservice', 'computron', 'com'): 4,
#          ('computron', 'com', 'tel'): 4,
#          ('com', 'tel', 'prices'): 4,
#          ('tel', 'prices', 'u'): 4,
#          ('prices', 'u', 'dollars'): 4,
#          ('u', 'dollars', 'ex'): 4,
#          ('dollars', 'ex', 'works'): 4,
#          ('ex', 'works', 'fax'): 4,
#          ('works', 'fax', 'jebel'): 4,
#          ('fax', 'jebel', 'ali'): 4,
#          ('jebel', 'ali', 'duty'): 4,
#          ('duty', 'free', 'zone'): 4,
#          ('free', 'zone', 'www'): 4,
#          ('zone', 'www', 'computron'): 4,
#          ('computron', 'com', 'prices'): 4,
#          ('com', 'prices', 'availability'): 4,
#          ('prices', 'availability', 'subject'): 4,
#          ('availability', 'subject', 'change'): 4,
#          ('subject', 'change', 'usa'): 4,
#          ('change', 'usa', 'canada'): 4,
#          ('usa', 'canada', 'u'): 4,
#          ('canada', 'u', 'e'): 4,
#          ('u', 'e', 'without'): 4,
#          ('e', 'without', 'notice'): 4,
#          ('without', 'notice', 'receive'): 4,
#          ('notice', 'receive', 'special'): 4,
#          ('receive', 'special', 'offers'): 4,
#          ('special', 'offers', 'plain'): 4,
#          ('offers', 'plain', 'text'): 4,
#          ('plain', 'text', 'format'): 4,
#          ('text', 'format', 'reply'): 4,
#          ('format', 'reply', 'mail'): 4,
#          ('reply', 'mail', 'request'): 4,
#          ('mail', 'request', 'export'): 4,
#          ('request', 'export', 'email'): 4,
#          ('export', 'email', 'considered'): 4,
#          ('email', 'considered', 'spam'): 4,
#          ('considered', 'spam', 'long'): 4,
#          ('spam', 'long', 'include'): 4,
#          ('long', 'include', 'contact'): 4,
#          ('include', 'contact', 'information'): 4,
#          ('contact', 'information', 'remove'): 4,
#          ('information', 'remove', 'instructions'): 4,
#          ('remove', 'instructions', 'message'): 4,
#          ('instructions', 'message', 'intended'): 4,
#          ('message', 'intended', 'dealer'): 4,
#          ('intended', 'dealer', 'resellers'): 4,
#          ('dealer', 'resellers', 'somehow'): 4,
#          ('resellers', 'somehow', 'gotten'): 4,
#          ('somehow', 'gotten', 'list'): 4,
#          ('gotten', 'list', 'error'): 4,
#          ('list', 'error', 'reason'): 4,
#          ('error', 'reason', 'would'): 4,
#          ('reason', 'would', 'like'): 4,
#          ('would', 'like', 'removed'): 4,
#          ('like', 'removed', 'please'): 4,
#          ('removed', 'please', 'reply'): 4,
#          ('please', 'reply', 'remove'): 4,
#          ('reply', 'remove', 'subject'): 4,
#          ('remove', 'subject', 'line'): 4,
#          ('subject', 'line', 'message'): 4,
#          ('line', 'message', 'message'): 4,
#          ('message', 'message', 'sent'): 4,
#          ('message', 'sent', 'compliance'): 4,
#          ('sent', 'compliance', 'federal'): 4,
#          ('compliance', 'federal', 'legislation'): 4,
#          ('federal', 'legislation', 'commercial'): 4,
#          ('legislation', 'commercial', 'e'): 4,
#          ('commercial', 'e', 'mail'): 4,
#          ('e', 'mail', 'h'): 4,
#          ('mail', 'h', 'r'): 4,
#          ('h', 'r', 'section'): 4,
#          ('r', 'section', 'paragraph'): 4,
#          ('section', 'paragraph', 'e'): 4,
#          ('paragraph', 'e', 'bill'): 4,
#          ('e', 'bill', 'title'): 4,
#          ('bill', 'title', 'iii'): 4,
#          ('title', 'iii', 'passed'): 4,
#          ('iii', 'passed', 'th'): 4,
#          ('passed', 'th', 'u'): 4,
#          ('th', 'u', 'congress'): 4,
#          ('u', 'congress', 'logos'): 4,
#          ('congress', 'logos', 'trademarks'): 4,
#          ('logos', 'trademarks', 'property'): 4,
#          ('trademarks', 'property', 'respective'): 4,
#          ('products', 'may', 'exactly'): 4,
#          ('may', 'exactly', 'shown'): 4,
#          ('exactly', 'shown', 'unsubscribe'): 4,
#          ('shown', 'unsubscribe', 'computron'): 4,
#          ('unsubscribe', 'computron', 'follow'): 4,
#          ('computron', 'follow', 'link'): 4,
#          ('follow', 'link', 'click'): 4,
#          ('link', 'click', 'link'): 4,
#          ('click', 'link', 'copy'): 4,
#          ('link', 'copy', 'paste'): 4,
#          ('copy', 'paste', 'address'): 4,
#          ('paste', 'address', 'browser'): 4,
#          ('address', 'browser', 'please'): 4,
#          ('browser', 'please', 'give'): 4,
#          ('please', 'give', 'atleast'): 4,
#          ('give', 'atleast', 'hours'): 4,
#          ('atleast', 'hours', 'unsubscription'): 4,
#          ('hours', 'unsubscription', 'effective'): 4,
#          ('price', 'low', 'price'): 4,
#          ('iit', 'demokritos', 'gr'): 4,
#          ('de', 'la', 'vente'): 4,
#          ('internet', 'protocol', 'voip'): 3,
#          ('announced', 'today', 'entered'): 3,
#          ('within', 'meaning', 'section'): 3,
#          ('meaning', 'section', 'securities'): 3,
#          ('section', 'securities', 'act'): 3,
#          ('securities', 'act', 'section'): 3,
#          ('act', 'section', 'b'): 3,
#          ('section', 'b', 'securities'): 3,
#          ('exchange', 'act', 'statements'): 3,
#          ('discussions', 'respect', 'predictions'): 3,
#          ('expectations', 'beliefs', 'plans'): 3,
#          ('beliefs', 'plans', 'projections'): 3,
#          ('plans', 'projections', 'objectives'): 3,
#          ('performance', 'statements', 'historical'): 3,
#          ('statements', 'historical', 'fact'): 3,
#          ('historical', 'fact', 'may'): 3,
#          ('statements', 'based', 'expectations'): 3,
#          ('based', 'expectations', 'estimates'): 3,
#          ('expectations', 'estimates', 'projections'): 3,
#          ('estimates', 'projections', 'time'): 3,
#          ('projections', 'time', 'statements'): 3,
#          ('time', 'statements', 'made'): 3,
#          ('statements', 'made', 'involve'): 3,
#          ('made', 'involve', 'number'): 3,
#          ('involve', 'number', 'risks'): 3,
#          ('cause', 'actual', 'results'): 3,
#          ('actual', 'results', 'events'): 3,
#          ('results', 'events', 'differ'): 3,
#          ('statements', 'action', 'may'): 3,
#          ('action', 'may', 'identified'): 3,
#          ('may', 'identified', 'use'): 3,
#          ('identified', 'use', 'words'): 3,
#          ('use', 'words', 'projects'): 3,
#          ('words', 'projects', 'foresee'): 3,
#          ('projects', 'foresee', 'expects'): 3,
#          ('estimates', 'believes', 'understands'): 3,
#          ('statements', 'indicating', 'certain'): 3,
#          ('indicating', 'certain', 'actions'): 3,
#          ('certain', 'actions', 'may'): 3,
#          ('advises', 'readers', 'subscribers'): 3,
#          ('readers', 'subscribers', 'seek'): 3,
#          ('subscribers', 'seek', 'advice'): 3,
#          ('advice', 'registered', 'professional'): 3,
#          ('registered', 'professional', 'securities'): 3,
#          ('professional', 'securities', 'representative'): 3,
#          ('material', 'within', 'report'): 3,
#          ('aware', 'inherent', 'conflict'): 3,
#          ('conflict', 'interest', 'resulting'): 3,
#          ('please', 'advised', 'nothing'): 3,
#          ('advised', 'nothing', 'within'): 3,
#          ('nothing', 'within', 'email'): 3,
#          ('within', 'email', 'shall'): 3,
#          ('herein', 'newsletter', 'neither'): 3,
#          ('newsletter', 'neither', 'registered'): 3,
#          ('neither', 'registered', 'investment'): 3,
#          ('registered', 'investment', 'advisor'): 3,
#          ('investment', 'advisor', 'affiliated'): 3,
#          ('subject', 'vic', 'odin'): 3,
#          ('vic', 'odin', 'n'): 3,
#          ('odin', 'n', 'ow'): 3,
#          ('n', 'ow', 'berne'): 3,
#          ('ow', 'berne', 'hotbox'): 3,
#          ('berne', 'hotbox', 'carnal'): 3,
#          ('hotbox', 'carnal', 'bride'): 3,
#          ('carnal', 'bride', 'cutworm'): 3,
#          ('bride', 'cutworm', 'dyadic'): 3,
#          ('cutworm', 'dyadic', 'guardia'): 3,
#          ('dyadic', 'guardia', 'continuous'): 3,
#          ('guardia', 'continuous', 'born'): 3,
#          ('continuous', 'born', 'gremlin'): 3,
#          ('born', 'gremlin', 'akin'): 3,
#          ('gremlin', 'akin', 'counterflow'): 3,
#          ('akin', 'counterflow', 'hereafter'): 3,
#          ('counterflow', 'hereafter', 'vocabularian'): 3,
#          ('hereafter', 'vocabularian', 'pessimum'): 3,
#          ('vocabularian', 'pessimum', 'yaounde'): 3,
#          ('pessimum', 'yaounde', 'cannel'): 3,
#          ('yaounde', 'cannel', 'bitch'): 3,
#          ('cannel', 'bitch', 'penetrate'): 3,
#          ('bitch', 'penetrate', 'demagogue'): 3,
#          ('penetrate', 'demagogue', 'arbitrary'): 3,
#          ('demagogue', 'arbitrary', 'egregious'): 3,
#          ('arbitrary', 'egregious', 'adenosine'): 3,
#          ('egregious', 'adenosine', 'rubin'): 3,
#          ('adenosine', 'rubin', 'gil'): 3,
#          ('rubin', 'gil', 'luminosity'): 3,
#          ('gil', 'luminosity', 'delicti'): 3,
#          ('luminosity', 'delicti', 'yarmulke'): 3,
#          ('delicti', 'yarmulke', 'sauterne'): 3,
#          ('yarmulke', 'sauterne', 'selfadjoint'): 3,
#          ('sauterne', 'selfadjoint', 'agleam'): 3,
#          ('selfadjoint', 'agleam', 'exeter'): 3,
#          ('agleam', 'exeter', 'picofarad'): 3,
#          ('exeter', 'picofarad', 'consulate'): 3,
#          ('picofarad', 'consulate', 'dichotomous'): 3,
#          ('consulate', 'dichotomous', 'boyhood'): 3,
#          ('dichotomous', 'boyhood', 'balfour'): 3,
#          ('boyhood', 'balfour', 'spheric'): 3,
#          ('balfour', 'spheric', 'frey'): 3,
#          ('spheric', 'frey', 'pillory'): 3,
#          ('frey', 'pillory', 'hoosier'): 3,
#          ('pillory', 'hoosier', 'fibonacci'): 3,
#          ('hoosier', 'fibonacci', 'cat'): 3,
#          ('fibonacci', 'cat', 'handful'): 3,
#          ('sales', 'department', 'details'): 3,
#          ('department', 'details', 'please'): 3,
#          ('retail', 'price', 'low'): 3,
#          ('yap', 'internationa', 'inc'): 3,
#          ('indicative', 'future', 'resuits'): 3,
#          ('mbps', 'wireless', 'firewall'): 3,
#          ('visit', 'http', 'www'): 3,
#          ('http', 'www', 'computron'): 3,
#          ('computron', 'com', 'deals'): 3,
#          ('property', 'respective', 'owners'): 3,
#          ('respective', 'owners', 'products'): 3,
#          ('owners', 'products', 'may'): 3,
#          ('gb', 'storage', 'drive'): 3,
#          ('de', 'l', 'art'): 3,
#          ('paliourg', 'iit', 'demokritos'): 3,
#          ('http', 'list', 'artauction'): 3,
#          ('list', 'artauction', 'net'): 3,
#          ('subject', 'vocable', 'rnd'): 2,
#          ('vocable', 'rnd', 'word'): 2,
#          ('rnd', 'word', 'asceticism'): 2,
#          ('word', 'asceticism', 'vcsc'): 2,
#          ('asceticism', 'vcsc', 'brand'): 2,
#          ('vcsc', 'brand', 'new'): 2,
#          ('brand', 'new', 'stock'): 2,
#          ('new', 'stock', 'attention'): 2,
#          ('stock', 'attention', 'vocalscape'): 2,
#          ('attention', 'vocalscape', 'inc'): 2,
#          ('vocalscape', 'inc', 'stock'): 2,
#          ('inc', 'stock', 'symbol'): 2,
#          ('stock', 'symbol', 'vcsc'): 2,
#          ('symbol', 'vcsc', 'vcsc'): 2,
#          ('vcsc', 'vcsc', 'top'): 2,
#          ('vcsc', 'top', 'stock'): 2,
#          ('top', 'stock', 'pick'): 2,
#          ('stock', 'pick', 'month'): 2,
#          ('pick', 'month', 'april'): 2,
#          ('month', 'april', 'stock'): 2,
#          ('april', 'stock', 'expected'): 2,
#          ('stock', 'expected', 'bounce'): 2,
#          ('expected', 'bounce', 'cents'): 2,
#          ('bounce', 'cents', 'level'): 2,
#          ('cents', 'level', 'stock'): 2,
#          ('level', 'stock', 'hit'): 2,
#          ('stock', 'hit', 'time'): 2,
#          ('hit', 'time', 'low'): 2,
#          ('time', 'low', 'bounce'): 2,
#          ('low', 'bounce', 'back'): 2,
#          ('bounce', 'back', 'stock'): 2,
#          ('back', 'stock', 'going'): 2,
#          ('stock', 'going', 'explode'): 2,
#          ('going', 'explode', 'next'): 2,
#          ('explode', 'next', 'days'): 2,
#          ('next', 'days', 'watch'): 2,
#          ('days', 'watch', 'soar'): 2,
#          ('watch', 'soar', 'watch'): 2,
#          ('soar', 'watch', 'stock'): 2,
#          ('watch', 'stock', 'go'): 2,
#          ('stock', 'go', 'crazy'): 2,
#          ('go', 'crazy', 'next'): 2,
#          ('crazy', 'next', 'week'): 2,
#          ('next', 'week', 'breaking'): 2,
#          ('week', 'breaking', 'news'): 2,
#          ('network', 'services', 'current'): 2,
#          ('services', 'current', 'price'): 2,
#          ('next', 'days', 'vocalscape'): 2,
#          ('days', 'vocalscape', 'networks'): 2,
#          ('vocalscape', 'networks', 'inc'): 2,
#          ('networks', 'inc', 'building'): 2,
#          ('inc', 'building', 'company'): 2,
#          ('building', 'company', 'revolutionizing'): 2,
#          ('company', 'revolutionizing', 'telecommunications'): 2,
#          ('revolutionizing', 'telecommunications', 'industry'): 2,
#          ('telecommunications', 'industry', 'affordable'): 2,
#          ('industry', 'affordable', 'phone'): 2,
#          ('affordable', 'phone', 'systems'): 2,
#          ('phone', 'systems', 'hardware'): 2,
#          ('systems', 'hardware', 'online'): 2,
#          ('hardware', 'online', 'software'): 2,
#          ('online', 'software', 'rates'): 2,
#          ('software', 'rates', 'canada'): 2,
#          ('rates', 'canada', 'us'): 2,
#          ('canada', 'us', 'vocalscape'): 2,
#          ('us', 'vocalscape', 'company'): 2,
#          ('vocalscape', 'company', 'global'): 2,
#          ('company', 'global', 'reach'): 2,
#          ('global', 'reach', 'receiving'): 2,
#          ('reach', 'receiving', 'international'): 2,
#          ('receiving', 'international', 'attention'): 2,
#          ('international', 'attention', 'development'): 2,
#          ('attention', 'development', 'voice'): 2,
#          ('development', 'voice', 'ip'): 2,
#          ('voice', 'ip', 'voip'): 2,
#          ('ip', 'voip', 'application'): 2,
#          ('voip', 'application', 'solutions'): 2,
#          ('application', 'solutions', 'including'): 2,
#          ('solutions', 'including', 'award'): 2,
#          ('including', 'award', 'winning'): 2,
#          ('award', 'winning', 'eyefontm'): 2,
#          ('winning', 'eyefontm', 'softphone'): 2,
#          ('eyefontm', 'softphone', 'real'): 2,
#          ('softphone', 'real', 'time'): 2,
#          ('real', 'time', 'pc'): 2,
#          ('time', 'pc', 'phone'): 2,
#          ('pc', 'phone', 'advanced'): 2,
#          ('phone', 'advanced', 'implementer'): 2,
#          ('advanced', 'implementer', 'pbx'): 2,
#          ('implementer', 'pbx', 'systems'): 2,
#          ('pbx', 'systems', 'companies'): 2,
#          ('systems', 'companies', 'call'): 2,
#          ('companies', 'call', 'centers'): 2,
#          ('call', 'centers', 'itsps'): 2,
#          ('centers', 'itsps', 'service'): 2,
#          ('itsps', 'service', 'providers'): 2,
#          ('service', 'providers', 'vocalscape'): 2,
#          ('providers', 'vocalscape', 'created'): 2,
#          ('vocalscape', 'created', 'software'): 2,
#          ('created', 'software', 'interactive'): 2,
#          ('software', 'interactive', 'solutions'): 2,
#          ('interactive', 'solutions', 'revolving'): 2,
#          ('solutions', 'revolving', 'around'): 2,
#          ('revolving', 'around', 'global'): 2,
#          ('around', 'global', 'communications'): 2,
#          ('global', 'communications', 'data'): 2,
#          ('communications', 'data', 'voice'): 2,
#          ('data', 'voice', 'convergence'): 2,
#          ('voice', 'convergence', 'companies'): 2,
#          ('convergence', 'companies', 'use'): 2,
#          ('companies', 'use', 'vocalscape'): 2,
#          ('use', 'vocalscape', 'voice'): 2,
#          ('vocalscape', 'voice', 'internet'): 2,
#          ('internet', 'protocol', 'applications'): 2,
#          ('protocol', 'applications', 'like'): 2,
#          ('applications', 'like', 'ip'): 2,
#          ('like', 'ip', 'pbxs'): 2,
#          ('ip', 'pbxs', 'softswitches'): 2,
#          ('pbxs', 'softswitches', 'pc'): 2,
#          ('softswitches', 'pc', 'phone'): 2,
#          ('pc', 'phone', 'web'): 2,
#          ('phone', 'web', 'phone'): 2,
#          ('web', 'phone', 'providing'): 2,
#          ('phone', 'providing', 'real'): 2,
#          ('providing', 'real', 'time'): 2,
#          ('real', 'time', 'human'): 2,
#          ('time', 'human', 'interaction'): 2,
#          ('human', 'interaction', 'information'): 2,
#          ('interaction', 'information', 'delivery'): 2,
#          ('information', 'delivery', 'internet'): 2,
#          ('delivery', 'internet', 'vocalscape'): 2,
#          ('internet', 'vocalscape', 'solutions'): 2,
#          ('vocalscape', 'solutions', 'businesses'): 2,
#          ('solutions', 'businesses', 'offer'): 2,
#          ('businesses', 'offer', 'quality'): 2,
#          ('offer', 'quality', 'voice'): 2,
#          ('quality', 'voice', 'service'): 2,
#          ('voice', 'service', 'anywhere'): 2,
#          ('service', 'anywhere', 'world'): 2,
#          ('anywhere', 'world', 'rates'): 2,
#          ('world', 'rates', 'significantly'): 2,
#          ('rates', 'significantly', 'lower'): 2,
#          ('significantly', 'lower', 'current'): 2,
#          ('lower', 'current', 'long'): 2,
#          ('current', 'long', 'distance'): 2,
#          ('long', 'distance', 'charges'): 2,
#          ('distance', 'charges', 'develop'): 2,
#          ('charges', 'develop', 'software'): 2,
#          ('develop', 'software', 'run'): 2,
#          ('software', 'run', 'voip'): 2,
#          ('run', 'voip', 'networks'): 2,
#          ('voip', 'networks', 'sell'): 2,
#          ('networks', 'sell', 'install'): 2,
#          ('sell', 'install', 'service'): 2,
#          ('install', 'service', 'branded'): 2,
#          ('service', 'branded', 'voip'): 2,
#          ('branded', 'voip', 'gateways'): 2,
#          ('voip', 'gateways', 'gatekeeper'): 2,
#          ('gateways', 'gatekeeper', 'control'): 2,
#          ('gatekeeper', 'control', 'software'): 2,
#          ('control', 'software', 'also'): 2,
#          ('software', 'also', 'license'): 2,
#          ('also', 'license', 'software'): 2,
#          ('license', 'software', 'customers'): 2,
#          ('software', 'customers', 'want'): 2,
#          ('customers', 'want', 'brand'): 2,
#          ('want', 'brand', 'voip'): 2,
#          ('brand', 'voip', 'solutions'): 2,
#          ('voip', 'solutions', 'vocalscape'): 2,
#          ('solutions', 'vocalscape', 'committed'): 2,
#          ('vocalscape', 'committed', 'making'): 2,
#          ('committed', 'making', 'great'): 2,
#          ('making', 'great', 'technology'): 2,
#          ('great', 'technology', 'challenging'): 2,
#          ('technology', 'challenging', 'status'): 2,
#          ('challenging', 'status', 'quo'): 2,
#          ('status', 'quo', 'building'): 2,
#          ('quo', 'building', 'st'): 2,
#          ('building', 'st', 'century'): 2,
#          ('st', 'century', 'company'): 2,
#          ('century', 'company', 'changes'): 2,
#          ('company', 'changes', 'way'): 2,
#          ('changes', 'way', 'businesses'): 2,
#          ('way', 'businesses', 'communicate'): 2,
#          ('businesses', 'communicate', 'interact'): 2,
#          ('communicate', 'interact', 'internet'): 2,
#          ('interact', 'internet', 'current'): 2,
#          ('internet', 'current', 'price'): 2,
#          ('next', 'days', 'breaking'): 2,
#          ('days', 'breaking', 'news'): 2,
#          ('network', 'services', 'katonah'): 2,
#          ('services', 'katonah', 'n'): 2,
#          ('katonah', 'n', 'prnewswire'): 2,
#          ('n', 'prnewswire', 'firstcall'): 2,
#          ('prnewswire', 'firstcall', 'via'): 2,
#          ('firstcall', 'via', 'comtex'): 2,
#          ('via', 'comtex', 'vocalscape'): 2,
#          ('comtex', 'vocalscape', 'inc'): 2,
#          ('vocalscape', 'inc', 'pink'): 2,
#          ('inc', 'pink', 'vcsc'): 2,
#          ('pink', 'vcsc', 'emerging'): 2,
#          ('vcsc', 'emerging', 'leader'): 2,
#          ('emerging', 'leader', 'development'): 2,
#          ('leader', 'development', 'voice'): 2,
#          ('development', 'voice', 'internet'): 2,
#          ('protocol', 'voip', 'telephony'): 2,
#          ('voip', 'telephony', 'solutions'): 2,
#          ('telephony', 'solutions', 'announced'): 2,
#          ('solutions', 'announced', 'today'): 2,
#          ('today', 'entered', 'sales'): 2,
#          ('entered', 'sales', 'agent'): 2,
#          ('sales', 'agent', 'agreement'): 2,
#          ('agent', 'agreement', 'mix'): 2,
#          ('agreement', 'mix', 'networks'): 2,
#          ('mix', 'networks', 'inc'): 2,
#          ('networks', 'inc', 'voip'): 2,
#          ('inc', 'voip', 'enhanced'): 2,
#          ('voip', 'enhanced', 'telephony'): 2,
#          ('enhanced', 'telephony', 'service'): 2,
#          ('telephony', 'service', 'provider'): 2,
#          ('service', 'provider', 'agreement'): 2,
#          ('provider', 'agreement', 'provides'): 2,
#          ('agreement', 'provides', 'vocalscape'): 2,
#          ('provides', 'vocalscape', 'turnkey'): 2,
#          ('vocalscape', 'turnkey', 'calling'): 2,
#          ('turnkey', 'calling', 'card'): 2,
#          ('calling', 'card', 'customers'): 2,
#          ('card', 'customers', 'access'): 2,
#          ('customers', 'access', 'mix'): 2,
#          ('access', 'mix', 'networks'): 2,
#          ('mix', 'networks', 'services'): 2,
#          ('networks', 'services', 'including'): 2,
#          ('services', 'including', 'north'): 2,
#          ('including', 'north', 'american'): 2,
#          ('north', 'american', 'dids'): 2,
#          ('american', 'dids', 'phone'): 2,
#          ('dids', 'phone', 'numbers'): 2,
#          ('phone', 'numbers', 'domestic'): 2,
#          ('numbers', 'domestic', 'long'): 2,
#          ('domestic', 'long', 'distance'): 2,
#          ('long', 'distance', 'termination'): 2,
#          ('distance', 'termination', 'vocalscape'): 2,
#          ('termination', 'vocalscape', 'also'): 2,
#          ('vocalscape', 'also', 'able'): 2,
#          ('also', 'able', 'supply'): 2,
#          ('able', 'supply', 'clients'): 2,
#          ('supply', 'clients', 'enhanced'): 2,
#          ('clients', 'enhanced', 'voip'): 2,
#          ('enhanced', 'voip', 'products'): 2,
#          ('voip', 'products', 'including'): 2,
#          ('products', 'including', 'pre'): 2,
#          ('including', 'pre', 'paid'): 2,
#          ('pre', 'paid', 'calling'): 2,
#          ('paid', 'calling', 'mix'): 2,
#          ('calling', 'mix', 'networks'): 2,
#          ('mix', 'networks', 'north'): 2,
#          ('networks', 'north', 'american'): 2,
#          ('north', 'american', 'network'): 2,
#          ('american', 'network', 'excited'): 2,
#          ('network', 'excited', 'help'): 2,
#          ('excited', 'help', 'companies'): 2,
#          ('help', 'companies', 'launch'): 2,
#          ('companies', 'launch', 'voip'): 2,
#          ('launch', 'voip', 'business'): 2,
#          ('voip', 'business', 'models'): 2,
#          ('business', 'models', 'using'): 2,
#          ('models', 'using', 'solution'): 2,
#          ('using', 'solution', 'whole'): 2,
#          ('solution', 'whole', 'picture'): 2,
#          ('whole', 'picture', 'software'): 2,
#          ('picture', 'software', 'network'): 2,
#          ('software', 'network', 'needed'): 2,
#          ('network', 'needed', 'route'): 2,
#          ('needed', 'route', 'calls'): 2,
#          ('route', 'calls', 'mix'): 2,
#          ('calls', 'mix', 'networks'): 2,
#          ('mix', 'networks', 'gives'): 2,
#          ('networks', 'gives', 'us'): 2,
#          ('gives', 'us', 'ability'): 2,
#          ('us', 'ability', 'offer'): 2,
#          ('ability', 'offer', 'wholesale'): 2,
#          ('offer', 'wholesale', 'monthly'): 2,
#          ('wholesale', 'monthly', 'flat'): 2,
#          ('monthly', 'flat', 'rate'): 2,
#          ('flat', 'rate', 'plans'): 2,
#          ('rate', 'plans', 'dids'): 2,
#          ('plans', 'dids', 'clients'): 2,
#          ('dids', 'clients', 'allow'): 2,
#          ('clients', 'allow', 'us'): 2,
#          ('allow', 'us', 'build'): 2,
#          ('us', 'build', 'business'): 2,
#          ('build', 'business', 'models'): 2,
#          ('business', 'models', 'like'): 2,
#          ('models', 'like', 'popular'): 2,
#          ('like', 'popular', 'voip'): 2,
#          ('popular', 'voip', 'companies'): 2,
#          ('voip', 'companies', 'vonage'): 2,
#          ('companies', 'vonage', 'packet'): 2,
#          ('vonage', 'packet', 'says'): 2,
#          ('packet', 'says', 'ryan'): 2,
#          ('says', 'ryan', 'gibson'): 2,
#          ('ryan', 'gibson', 'vp'): 2,
#          ('gibson', 'vp', 'vocalscape'): 2,
#          ('vp', 'vocalscape', 'networks'): 2,
#          ('vocalscape', 'networks', 'legal'): 2,
#          ('networks', 'legal', 'words'): 2,
#          ('legal', 'words', 'continue'): 2,
#          ('words', 'continue', 'information'): 2,
#          ('continue', 'information', 'within'): 2,
#          ('information', 'within', 'email'): 2,
#          ('within', 'email', 'contains'): 2,
#          ('email', 'contains', 'forward'): 2,
#          ('contains', 'forward', 'looking'): 2,
#          ('act', 'statements', 'express'): 2,
#          ('statements', 'express', 'involve'): 2,
#          ('express', 'involve', 'discussions'): 2,
#          ('involve', 'discussions', 'respect'): 2,
#          ('respect', 'predictions', 'goals'): 2,
#          ('predictions', 'goals', 'expectations'): 2,
#          ('goals', 'expectations', 'beliefs'): 2,
#          ('projections', 'objectives', 'assumptions'): 2,
#          ('objectives', 'assumptions', 'future'): 2,
#          ('assumptions', 'future', 'events'): 2,
#          ('future', 'events', 'performance'): 2,
#          ('events', 'performance', 'statements'): 2,
#          ('fact', 'may', 'forward'): 2,
#          ('may', 'forward', 'looking'): 2,
#          ('looking', 'statements', 'forward'): 2,
#          ('statements', 'forward', 'looking'): 2,
#          ('could', 'cause', 'actual'): 2,
#          ('events', 'differ', 'materially'): 2,
#          ('differ', 'materially', 'presently'): 2,
#          ('materially', 'presently', 'anticipated'): 2,
#          ('presently', 'anticipated', 'forward'): 2,
#          ('anticipated', 'forward', 'looking'): 2,
#          ('looking', 'statements', 'action'): 2,
#          ('foresee', 'expects', 'estimates'): 2,
#          ('expects', 'estimates', 'believes'): 2,
#          ('believes', 'understands', 'part'): 2,
#          ('understands', 'part', 'anticipates'): 2,
#          ('part', 'anticipates', 'statements'): 2,
#          ('anticipates', 'statements', 'indicating'): 2,
#          ('actions', 'may', 'could'): 2,
#          ('may', 'could', 'might'): 2,
#          ('could', 'might', 'occur'): 2,
#          ('might', 'occur', 'information'): 2,
#          ('occur', 'information', 'provided'): 2,
#          ('provided', 'within', 'email'): 2,
#          ('within', 'email', 'pertaining'): 2,
#          ('email', 'pertaining', 'investing'): 2,
#          ('investment', 'advice', 'emerging'): 2,
#          ('advice', 'emerging', 'equity'): 2,
#          ('emerging', 'equity', 'alert'): 2,
#          ('equity', 'alert', 'advises'): 2,
#          ('alert', 'advises', 'readers'): 2,
#          ('featured', 'within', 'email'): 2,
#          ('within', 'email', 'none'): 2,
#          ('email', 'none', 'material'): 2,
#          ('none', 'material', 'within'): 2,
#          ('within', 'report', 'shall'): 2,
#          ('report', 'shall', 'construed'): 2,
#          ('shall', 'construed', 'kind'): 2,
#          ('investment', 'advice', 'please'): 2,
#          ('advice', 'please', 'mind'): 2,
#          ('please', 'mind', 'interpretation'): 2,
#          ('mind', 'interpretation', 'witer'): 2,
#          ('interpretation', 'witer', 'newsletter'): 2,
#          ('witer', 'newsletter', 'news'): 2,
#          ('newsletter', 'news', 'published'): 2,
#          ('news', 'published', 'company'): 2,
#          ('published', 'company', 'represent'): 2,
#          ('company', 'represent', 'company'): 2,
#          ('represent', 'company', 'official'): 2,
#          ('company', 'official', 'statement'): 2,
#          ('official', 'statement', 'fact'): 2,
#          ('statement', 'fact', 'may'): 2,
#          ('fact', 'may', 'differ'): 2,
#          ('may', 'differ', 'real'): 2,
#          ('differ', 'real', 'meaning'): 2,
#          ('real', 'meaning', 'news'): 2,
#          ('meaning', 'news', 'release'): 2,
#          ('news', 'release', 'meant'): 2,
#          ('release', 'meant', 'say'): 2,
#          ('meant', 'say', 'look'): 2,
#          ('say', 'look', 'news'): 2,
#          ('look', 'news', 'release'): 2,
#          ('news', 'release', 'judge'): 2,
#          ('release', 'judge', 'details'): 2,
#          ('judge', 'details', 'compliance'): 2,
#          ('details', 'compliance', 'section'): 2,
#          ('compliance', 'section', 'b'): 2,
#          ('section', 'b', 'disclose'): 2,
#          ('b', 'disclose', 'holding'): 2,
#          ('disclose', 'holding', 'vcsc'): 2,
#          ('holding', 'vcsc', 'shares'): 2,
#          ('vcsc', 'shares', 'prior'): 2,
#          ('shares', 'prior', 'publication'): 2,
#          ('prior', 'publication', 'report'): 2,
#          ('publication', 'report', 'aware'): 2,
#          ('report', 'aware', 'inherent'): 2,
#          ('interest', 'resulting', 'holdings'): 2,
#          ('resulting', 'holdings', 'due'): 2,
#          ('holdings', 'due', 'intent'): 2,
#          ('due', 'intent', 'profit'): 2,
#          ('intent', 'profit', 'liquidation'): 2,
#          ('profit', 'liquidation', 'shares'): 2,
#          ('liquidation', 'shares', 'shares'): 2,
#          ('shares', 'shares', 'may'): 2,
#          ('shares', 'may', 'sold'): 2,
#          ('may', 'sold', 'time'): 2,
#          ('sold', 'time', 'even'): 2,
#          ('time', 'even', 'positive'): 2,
#          ('even', 'positive', 'statements'): 2,
#          ('positive', 'statements', 'made'): 2,
#          ('statements', 'made', 'regarding'): 2,
#          ('made', 'regarding', 'company'): 2,
#          ('regarding', 'company', 'since'): 2,
#          ('company', 'since', 'shares'): 2,
#          ('since', 'shares', 'inherent'): 2,
#          ('shares', 'inherent', 'conflict'): 2,
#          ('conflict', 'interest', 'statements'): 2,
#          ('interest', 'statements', 'opinions'): 2,
#          ('statements', 'opinions', 'readers'): 2,
#          ('opinions', 'readers', 'publication'): 2,
#          ('readers', 'publication', 'cautioned'): 2,
#          ('publication', 'cautioned', 'place'): 2,
#          ('cautioned', 'place', 'undue'): 2,
#          ('place', 'undue', 'reliance'): 2,
#          ('undue', 'reliance', 'forward'): 2,
#          ('reliance', 'forward', 'looking'): 2,
#          ('statements', 'based', 'certain'): 2,
#          ('based', 'certain', 'assumptions'): 2,
#          ('certain', 'assumptions', 'expectations'): 2,
#          ('assumptions', 'expectations', 'involving'): 2,
#          ('expectations', 'involving', 'various'): 2,
#          ('involving', 'various', 'risks'): 2,
#          ('various', 'risks', 'uncertainties'): 2,
#          ('could', 'cause', 'results'): 2,
#          ('cause', 'results', 'differ'): 2,
#          ('results', 'differ', 'materially'): 2,
#          ('differ', 'materially', 'set'): 2,
#          ('materially', 'set', 'forth'): 2,
#          ('set', 'forth', 'forward'): 2,
#          ('forth', 'forward', 'looking'): 2,
#          ('looking', 'statements', 'please'): 2,
#          ('statements', 'please', 'advised'): 2,
#          ('email', 'shall', 'constitute'): 2,
#          ('shall', 'constitute', 'solicitation'): 2,
#          ('constitute', 'solicitation', 'invitation'): 2,
#          ('solicitation', 'invitation', 'get'): 2,
#          ('invitation', 'get', 'position'): 2,
#          ('get', 'position', 'sell'): 2,
#          ('position', 'sell', 'security'): 2,
#          ('sell', 'security', 'mentioned'): 2,
#          ('security', 'mentioned', 'herein'): 2,
#          ('mentioned', 'herein', 'newsletter'): 2,
#          ('advisor', 'affiliated', 'broker'): 2,
#          ('affiliated', 'broker', 'dealer'): 2,
#          ('broker', 'dealer', 'newsletter'): 2,
#          ('dealer', 'newsletter', 'paid'): 2,
#          ('newsletter', 'paid', 'third'): 2,
#          ('paid', 'third', 'party'): 2,
#          ('third', 'party', 'send'): 2,
#          ('party', 'send', 'report'): 2,
#          ('send', 'report', 'statements'): 2,
#          ('report', 'statements', 'made'): 2,
#          ('statements', 'made', 'express'): 2,
#          ('made', 'express', 'opinion'): 2,
#          ('express', 'opinion', 'treated'): 2,
#          ('opinion', 'treated', 'may'): 2,
#          ('treated', 'may', 'take'): 2,
#          ('may', 'take', 'position'): 2,
#          ('take', 'position', 'sell'): 2,
#          ('position', 'sell', 'securities'): 2,
#          ('sell', 'securities', 'mentioned'): 2,
#          ('securities', 'mentioned', 'time'): 2,
#          ('mentioned', 'time', 'report'): 2,
#          ('time', 'report', 'includes'): 2,
#          ('report', 'includes', 'forward'): 2,
#          ('includes', 'forward', 'looking'): 2,
#          ('within', 'meaning', 'private'): 2,
#          ('meaning', 'private', 'securities'): 2,
#          ('private', 'securities', 'litigation'): 2,
#          ('securities', 'litigation', 'reform'): 2,
#          ('litigation', 'reform', 'act'): 2,
#          ('reform', 'act', 'statements'): 2,
#          ('act', 'statements', 'may'): 2,
#          ('statements', 'may', 'include'): 2,
#          ('may', 'include', 'terms'): 2,
#          ('include', 'terms', 'projected'): 2,
#          ('terms', 'projected', 'speculative'): 2,
#          ('speculative', 'price', 'expect'): 2,
#          ('price', 'expect', 'believe'): 2,
#          ('expect', 'believe', 'may'): 2,
#          ('believe', 'may', 'soar'): 2,
#          ('may', 'soar', 'move'): 2,
#          ('soar', 'move', 'undervalued'): 2,
#          ('move', 'undervalued', 'intend'): 2,
#          ('undervalued', 'intend', 'similar'): 2,
#          ('intend', 'similar', 'terms'): 2,
#          ('oil', 'gas', 'inc'): 2,
#          ('gas', 'inc', 'mogi'): 2,
#          ('montana', 'oi', 'gas'): 2,
#          ('lake', 'oil', 'gas'): 2,
#          ('sylvan', 'lake', 'project'): 2,
#          ('detailed', 'project', 'description'): 2,
#          ('sylvan', 'lake', 'field'): 2,
#          ('freehold', 'mineral', 'rights'): 2,
#          ('mineral', 'rights', 'owner'): 2,
#          ('one', 'quarter', 'section'): 2,
#          ('section', 'spacing', 'acres'): 2,
#          ('gas', 'processing', 'facility'): 2,
#          ('watch', 'one', 'trade'): 2,
#          ('mb', 'ddr', 'ram'): 2,
#          ('ddr', 'ram', 'sodimm'): 2,
#          ('diamond', 'supramax', 'k'): 2,
#          ('supramax', 'k', 'usb'): 2,
#          ('logitech', 'io', 'personal'): 2,
#          ('io', 'personal', 'digital'): 2,
#          ('personal', 'digital', 'pen'): 2,
#          ('notebookplus', 'mobile', 'mini'): 2,
#          ('mobile', 'mini', 'usb'): 2,
#          ('mini', 'usb', 'keypad'): 2,
#          ('gsm', 'usb', 'sim'): 2,
#          ('usb', 'sim', 'card'): 2,
#          ('sim', 'card', 'reader'): 2,
#          ('money', 'back', 'guarantee'): 2,
#          ('low', 'price', 'savxe'): 2,
#          ('dr', 'abdul', 'kareem'): 2,
#          ('ab', 'karol', 'fastermail'): 2,
#          ('karol', 'fastermail', 'com'): 2,
#          ('late', 'sir', 'engr'): 2,
#          ('sir', 'engr', 'john'): 2,
#          ('engr', 'john', 'scott'): 2,
#          ('late', 'sir', 'john'): 2,
#          ('sir', 'john', 'scott'): 2,
#          ('internationa', 'inc', 'ypil'): 2,
#          ('voip', 'technoiogy', 'requires'): 2,
#          ('technoiogy', 'requires', 'computer'): 2,
#          ('requires', 'computer', 'high'): 2,
#          ('computer', 'high', 'speed'): 2,
#          ('high', 'speed', 'internet'): 2,
#          ('speed', 'internet', 'connection'): 2,
#          ('us', 'dollar', 'oo'): 2,
#          ('dollar', 'oo', 'oo'): 2,
#          ('yap', 'internationa', 'announced'): 2,
#          ('ooking', 'statements', 'based'): 2,
#          ('risks', 'uncertainties', 'factors'): 2,
#          ('statements', 'many', 'microcap'): 2,
#          ('many', 'microcap', 'stocks'): 2,
#          ('represent', 'information', 'contained'): 2,
#          ('information', 'contained', 'message'): 2,
#          ('contained', 'message', 'states'): 2,
#          ('fact', 'necessary', 'make'): 2,
#          ('necessary', 'make', 'statements'): 2,
#          ('make', 'statements', 'therein'): 2,
#          ('al', 'information', 'provided'): 2,
#          ('investment', 'advice', 'publisher'): 2,
#          ('advice', 'publisher', 'newsletter'): 2,
#          ('publisher', 'newsletter', 'advises'): 2,
#          ('none', 'materia', 'within'): 2,
#          ('materia', 'within', 'report'): 2,
#          ('within', 'report', 'shail'): 2,
#          ('report', 'shail', 'construed'): 2,
#          ('shail', 'construed', 'kind'): 2,
#          ('investment', 'advice', 'soiicitation'): 2,
#          ('advice', 'soiicitation', 'many'): 2,
#          ('soiicitation', 'many', 'companies'): 2,
#          ('many', 'companies', 'verge'): 2,
#          ('companies', 'verge', 'bankruptcy'): 2,
#          ('money', 'investing', 'stock'): 2,
#          ('investing', 'stock', 'publisher'): 2,
#          ('registered', 'investment', 'expert'): 2,
#          ('investment', 'expert', 'subscribers'): 2,
#          ('expert', 'subscribers', 'view'): 2,
#          ('subscribers', 'view', 'information'): 2,
#          ('view', 'information', 'herein'): 2,
#          ('information', 'herein', 'lega'): 2,
#          ('herein', 'lega', 'tax'): 2,
#          ('lega', 'tax', 'accounting'): 2,
#          ('tax', 'accounting', 'investment'): 2,
#          ('accounting', 'investment', 'advice'): 2,
#          ('investment', 'advice', 'reference'): 2,
#          ('advice', 'reference', 'past'): 2,
#          ('seiected', 'referenced', 'based'): 2,
#          ('performance', 'companies', 'wouid'): 2,
#          ('companies', 'wouid', 'need'): 2,
#          ('wouid', 'need', 'perfect'): 2,
#          ('need', 'perfect', 'timing'): 2,
#          ('exampies', 'given', 'assurance'): 2,
#          ('given', 'assurance', 'happening'): 2,
#          ('assurance', 'happening', 'remember'): 2,
#          ('past', 'performance', 'indicative'): 2,
#          ('performance', 'indicative', 'future'): 2,
#          ('future', 'resuits', 'thorough'): 2,
#          ('resuits', 'thorough', 'due'): 2,
#          ('effort', 'including', 'review'): 2,
#          ('completed', 'prior', 'investing'): 2,
#          ('ail', 'factual', 'information'): 2,
#          ('factual', 'information', 'report'): 2,
#          ('information', 'report', 'gathered'): 2,
#          ('report', 'gathered', 'public'): 2,
#          ('gathered', 'public', 'sources'): 2,
#          ('company', 'press', 'releases'): 2,
#          ('third', 'party', 'officer'): 2,
#          ('party', 'officer', 'director'): 2,
#          ('officer', 'director', 'affiliate'): 2,
#          ('compensation', 'due', 'fact'): 2,
#          ('due', 'fact', 'paid'): 2,
#          ('fact', 'paid', 'pubiication'): 2,
#          ('make', 'assurance', 'accuracy'): 2,
#          ('constitutes', 'acceptance', 'terms'): 2,
#          ('blood', 'flow', 'penis'): 2,
#          ('http', 'www', 'hosting'): 2,
#          ('www', 'hosting', 'com'): 2,
#          ('phone', 'mobile', 'email'): 2,
#          ('wireless', 'firewall', 'port'): 2,
#          ('firewall', 'port', 'router'): 2,
#          ('com', 'deals', 'one'): 2,
#          ('deals', 'one', 'stop'): 2,
#          ('joint', 'venture', 'agreement'): 2,
#          ('venture', 'agreement', 'anticipated'): 2,
#          ('tinydrive', 'usb', 'mobile'): 2,
#          ('usb', 'mobile', 'gb'): 2,
#          ('mobile', 'gb', 'storage'): 2,
#          ('storage', 'drive', 'tinydrive'): 2,
#          ('lightweight', 'compact', 'design'): 2,
#          ('data', 'transfer', 'rate'): 2,
#          ('powerful', 'weightloss', 'available'): 2,
#          ('href', 'http', 'www'): 2,
#          ('http', 'cordoned', 'net'): 2,
#          ('mrs', 'juliana', 'mbuluku'): 2,
#          ('age', 'nbsp', 'r'): 2,
#          ('medianet', 'group', 'technologies'): 2,
#          ('personal', 'research', 'eur'): 2,
#          ('research', 'eur', 'usd'): 2,
#          ('example', 'personal', 'research'): 2,
#          ('personal', 'research', 'artprice'): 2,
#          ('us', 'per', 'month'): 2,
#          ('welt', 'leader', 'kunstmarkt'): 2,
#          ('leader', 'kunstmarkt', 'infos'): 2,
#          ('kunstmarkt', 'infos', 'thierryehrmann'): 2,
#          ('catalogue', 'de', 'vente'): 2,
#          ('nous', 'pouvons', 'vous'): 2,
#          ('du', 'contexte', 'de'): 2,
#          ('contexte', 'de', 'la'): 2,
#          ('de', 'la', 'reproduction'): 2,
#          ('la', 'reproduction', 'de'): 2,
#          ('reproduction', 'de', 'l'): 2,
#          ('de', 'l', 'uvre'): 2,
#          ('la', 'liste', 'des'): 2,
#          ('une', 'personal', 'research'): 2,
#          ('vente', 'la', 'page'): 2,
#          ('personal', 'research', 'pour'): 2,
#          ('research', 'pour', 'commander'): 2,
#          ('une', 'recherche', 'documentaire'): 2,
#          ('en', 'matire', 'de'): 2,
#          ('march', 'de', 'l'): 2,
#          ('email', 'paliourg', 'iit'): 2,
#          ('subject', 'time', 'right'): 2,
#          ('time', 'right', 'invest'): 2,
#          ('right', 'invest', 'euro'): 2,
#          ('invest', 'euro', 'london'): 2,
#          ('euro', 'london', 'ap'): 2,
#          ('london', 'ap', 'worldstream'): 2,
#          ('ap', 'worldstream', 'via'): 2,
#          ('worldstream', 'via', 'comtex'): 2,
#          ('via', 'comtex', 'u'): 2,
#          ('comtex', 'u', 'dollar'): 2,
#          ('u', 'dollar', 'fallen'): 2,
#          ('dollar', 'fallen', 'time'): 2,
#          ('fallen', 'time', 'low'): 2,
#          ('time', 'low', 'euro'): 2,
#          ...})

# %% [markdown]
# # Generate graph for top 10 N-grams

# %%
# Top 10 most common trigrams
most_common_trigrams = trigram_counts.most_common(10)

# Extract trigram labels and counts for the bar chart
trigram_labels, trigram_counts = zip(*most_common_trigrams)

# Convert each trigram tuple into a string
trigram_labels = [' '.join(trigram) for trigram in trigram_labels]

# Generate a list of colors from a colormap
colors = plt.cm.plasma(np.linspace(0, 1, len(trigram_labels)))

plt.figure(figsize=(10, 6))

# Create a horizontal bar chart with different colors for each bar
for i, (label, count) in enumerate(zip(trigram_labels, trigram_counts)):
    plt.barh(label, count, color=colors[i])

plt.xlabel('Frequency')
plt.ylabel('Trigrams')
plt.title(f'Top 10 Most Common Trigrams For Email Spams')

# Set the background color
plt.gca().set_facecolor('lightgrey')

# Invert the y-axis to display the most common trigrams at the top
plt.gca().invert_yaxis()

plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))

plt.show()
